# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/dataset_v1_kaggle.csv')
df.head()
# Out:
#     post_id            timestamp platform    user_id  \
# 0  6bcf29c5  2024-07-15 03:26:02  Twitter  user_1947
# 1  f91c8e39  2024-01-30 07:34:40  Twitter  user_8255
# 2  5b66edf1  2022-11-24 10:48:27  Twitter  user_3908
# 3  d709cd45  2023-09-26 17:34:44  Twitter  user_1244
# 4  b8313a62  2024-03-16 07:56:28  Twitter  user_6006
#
#                                                 text      label language  \
# 0  Quickly city or call score standard want. Thes...    hateful       en
# 1        Thought fund whole me. You are such a dumb!  offensive       en
# 2  Close establish table remember us. You are suc...  offensive       en
# 3  Office activity between note analysis series o...    hateful       en
# 4  Attention stay ever international available. Y...  offensive       en
#
#                                    preprocessed_text
# 0  quickly city or call score standard these peop...
# 1                  thought fund whole you are such a
# ...

# %%
for i, row in df[0:20].iterrows():

    print("Comment :", row["text"], '|', row['label'])
    print("-"*50)
# Out:
# Comment : Quickly city or call score standard want. These people are hate! | hateful
# --------------------------------------------------
# Comment : Thought fund whole me. You are such a dumb! | offensive
# --------------------------------------------------
# Comment : Close establish table remember us. You are such a stupid! | offensive
# --------------------------------------------------
# Comment : Office activity between note analysis series our. These people are plague! | hateful
# --------------------------------------------------
# Comment : Attention stay ever international available. You are such a stupid! | offensive
# --------------------------------------------------
# Comment : Republican memory factor capital spend. | neutral
# --------------------------------------------------
# Comment : Team line opportunity actually. These people are filthy! | hateful
# --------------------------------------------------
# ...
